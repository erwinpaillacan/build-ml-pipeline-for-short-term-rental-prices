# %%
import wandb
import pandas as pd

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_y/qpys3pq95mdfjrn4dvv7jzn00000gp/T/ipykernel_62923/2106872671.py in <module>
# ----> 1 import wandb
#       2 import pandas as pd
#       3
#       4 run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
#       5 local_path = wandb.use_artifact("sample.csv:latest").file()
#
# ~/opt/anaconda3/envs/mlflow-c456bc1735dd86c87e342dd631bf573b7c7eb5dc/lib/python3.7/site-packages/wandb/__init__.py in <module>
#      36 if PY3:
#      37     TYPE_CHECKING = True
# ---> 38     from wandb import sdk as wandb_sdk
#      39 else:
#      40     from wandb import sdk_py27 as wandb_sdk
#
# ~/opt/anaconda3/envs/mlflow-c456bc1735dd86c87e342dd631bf573b7c7eb5dc/lib/python3.7/site-packages/wandb/sdk/__init__.py in <module>
#      10 from .wandb_config import Config  # noqa: F401
#      11 from .wandb_history import History  # noqa: F401
# ---> 12 from .wandb_init import init  # noqa: F401
#      13 from .wandb_login import login  # noqa: F401
#      14 from .wandb_run import finish  # noqa: F401
#
# ~/opt/anaconda3/envs/mlflow-c456bc1735dd86c87e342dd631bf573b7c7eb5dc/lib/python3.7/site-packages/wandb/sdk/wandb_init.py in <module>
#      27
#      28 from . import wandb_login, wandb_setup
# ---> 29 from .backend.backend import Backend
#      30 from .lib import filesystem, ipython, module, reporting, telemetry
#      31 from .lib import RunDisabled, SummaryDisabled
#
# ~/opt/anaconda3/envs/mlflow-c456bc1735dd86c87e342dd631bf573b7c7eb5dc/lib/python3.7/site-packages/wandb/sdk/backend/backend.py in <module>
#      16 import wandb
#      17
# ---> 18 from ..interface import interface
#      19 from ..internal.internal import wandb_internal
#      20
#
# ~/opt/anaconda3/envs/mlflow-c456bc1735dd86c87e342dd631bf573b7c7eb5dc/lib/python3.7/site-packages/wandb/sdk/interface/interface.py in <module>
#      16 import wandb
#      17 from wandb import data_types
# ---> 18 from wandb.proto import wandb_internal_pb2 as pb
#      19 from wandb.proto import wandb_telemetry_pb2 as tpb
#      20 from wandb.util import (
#
# ~/opt/anaconda3/envs/mlflow-c456bc1735dd86c87e342dd631bf573b7c7eb5dc/lib/python3.7/site-packages/wandb/proto/wandb_internal_pb2.py in <module>
#      13
#      14 from google.protobuf import timestamp_pb2 as google_dot_protobuf_dot_timestamp__pb2
# ---> 15 from wandb.proto import wandb_telemetry_pb2 as wandb_dot_proto_dot_wandb__telemetry__pb2
#      16
#      17
#
# ~/opt/anaconda3/envs/mlflow-c456bc1735dd86c87e342dd631bf573b7c7eb5dc/lib/python3.7/site-packages/wandb/proto/wandb_telemetry_pb2.py in <module>
#      38       message_type=None, enum_type=None, containing_type=None,
#      39       is_extension=False, extension_scope=None,
# ---> 40       serialized_options=None, file=DESCRIPTOR),
#      41     _descriptor.FieldDescriptor(
#      42       name='imports_finish', full_name='wandb_internal.TelemetryRecord.imports_finish', index=1,
#
# ~/opt/anaconda3/envs/mlflow-c456bc1735dd86c87e342dd631bf573b7c7eb5dc/lib/python3.7/site-packages/google/protobuf/descriptor.py in __new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     559                 has_default_value=True, containing_oneof=None, json_name=None,
#     560                 file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 561       _message.Message._CheckCalledFromGeneratedFile()
#     562       if is_extension:
#     563         return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
